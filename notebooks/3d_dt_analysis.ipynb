# %% [markdown]
# # Aim
# The aim of this notebook is to prototype an analysis pipeline for Thomas's data. Neurons, cilia all that we can wish for.
#
# ## Overview
# 3D Immunos for neurite, cilia, nuclei, (additionally basal body) -

# %% [markdown]
# # 1. Helper functions

# %%
import os
os.chdir("..")  # disgusting but quick fix
import limoncello as lc
import pyclesperanto_prototype as cle
from imaris_ims_file_reader.ims import ims
import numpy as np
import os
import re
from tqdm import tqdm
import pyclesperanto_prototype as cle
import matplotlib.pyplot as plt
import napari
from skimage.morphology import skeletonize, medial_axis
from skan.csr import skeleton_to_csgraph, Skeleton, summarize
from skan import draw
from skimage.feature import shape_index
from skimage.measure import regionprops
from scipy.spatial import cKDTree
import pandas as pd
from stackview import insight
from scipy.ndimage import distance_transform_edt

# %%
ims_path = r"H:\tlobri\03_Experiments\03_Neurite-Cilia\EXP_E6\EXP_E6_260219\post-hoc_405DAPI_488CG_568PCNT_647TUJ1\E4_CL5g_d5_405DAPI_488CG_561PCNT_647TUJ1_50k_2026-03-06_1_F00.ims"

a, meta = lc.load_image(ims_path)
# Out:
# Opening .ims file: \\idnas37.d.uzh.ch\G_MLS_RB_UHome$\acuoco\01_lab\B_double mutants\A_experiments\03_cep290-inpp5e\03_TUNEL\TUNEL cep290-inpp5e 3dpf\TUNEL_cep290 mut 3 dpf_Confocal - Blue_Confocal - Yellow_2025-04-08_Protocol 3_13.10.30.ims
# Opening readonly file: \\idnas37.d.uzh.ch\G_MLS_RB_UHome$\acuoco\01_lab\B_double mutants\A_experiments\03_cep290-inpp5e\03_TUNEL\TUNEL cep290-inpp5e 3dpf\TUNEL_cep290 mut 3 dpf_Confocal - Blue_Confocal - Yellow_2025-04-08_Protocol 3_13.10.30.ims
#
# Shape (T, C, Z, Y, X): (1, 2, 12, 2040, 2040)
# Number of timepoints: 1
# Number of channels: 2
# Image dimensions (Z, Y, X): (12, 2040, 2040)
# Z Resolution: 0.917
# XY Resolution: (0.152, 0.152)

# %% [markdown]
# If for some reason the meta data is not found in the .ims, in many Imaris exports there is a **metadata text file** next to the `.ims` file,
# for example:
# - `METH-PLTurbID-2h-pfa_2026-02-12_12.33.21.ims`
# - `METH-PLTurbID-2h-pfa_2026-02-12_12.33.21_metadata.txt`
#
# This step:
# - Looks for a matching `*_metadata.txt` file next to your `.ims`
# - Reads voxel sizes (pixel size in µm, Z-step in µm) and channel information
# - Stores these values so later steps can report **real volumes in µm³** instead of just voxel counts.
#
# If no metadata file is found, the notebook will keep using default voxel sizes (1.0 µm).

# %%
meta_text = lc.load_ims_metadata(ims_path)
# Out:
# Using metadata file:
#  H:\acuoco\01_lab\B_double mutants\A_experiments\03_cep290-inpp5e\03_TUNEL\TUNEL cep290-inpp5e 3dpf\TUNEL_cep290 mut 3 dpf_Confocal - Blue_Confocal - Yellow_2025-04-08_Protocol 3_13.10.30_metadata.txt
#
# Pixel size XY: 0.1523 µm
# Z step (StepSize): 1.0000 µm
# Wavelengths (nm): [445.0, 561.0]
#
# Stored voxel sizes: Z=1.0000 µm, Y=0.1523 µm, X=0.1523 µm

# %% [markdown]
# watch out as sometimes the format is inconsistent and resolutions are not found in the txt file they will default to 1

# %% [markdown]
# Select GPU for clesperanto library

# %%
print(cle.available_device_names(dev_type="gpu"))
cle.select_device('NVIDIA GeForce RTX 4090')  # optional but good practice
print(cle.get_device())
# Out:
# ['NVIDIA GeForce RTX 4090', 'gfx1036']
# <NVIDIA GeForce RTX 4090 on Platform: NVIDIA CUDA (1 refs)>

# %%
# Simple default colormaps for a few channels
DEFAULT_COLORMAPS = ["yellow", "green", "red", "blue", "magenta", "cyan"]
CHANNEL_NAMES = ["cilia", "neurites", "basal_bodies", "nuclei"]
scale = (meta['voxel_size'])
viewer = napari.Viewer(ndisplay=3)
viewer.dims.axis_labels = ['Z', 'Y', 'X']
def set_layer_scale(event):
    layer = event.value
    if hasattr(layer, 'scale'):
        layer.scale = scale

# Connect the function to layer insertion events
viewer.layers.events.inserted.connect(set_layer_scale)

T, C, Z, Y, X = a.shape

for c in range(C):
    #volume = (volumes[c] - volumes[c].min()) / (volumes[c].max() - volumes[c].min())  # min - max normalization 
    volume = a[0,c]
    cmap = DEFAULT_COLORMAPS[c % len(DEFAULT_COLORMAPS)]
    viewer.add_image(volume, name=f"Channel {CHANNEL_NAMES[c]}", colormap=cmap, blending="additive", scale=scale, units='um')

print("Napari viewer opened. Use the sliders to explore. Close the window to continue.")
napari.run()
# Out:
# Napari viewer opened. Use the sliders to explore. Close the window to continue.
# Assistant skips harvesting pyclesperanto as it's not installed.
# 2026-05-22 16:43:34.101 | INFO     | napari_assistant._gui._category_widget:call_op:185 - detect_label_edges (pyclesperanto_prototype)(..., )
# 2026-05-22 16:43:46.203 | INFO     | napari_assistant._gui._category_widget:call_op:185 - threshold_otsu (pyclesperanto_prototype)(..., )
# 2026-05-22 16:45:01.917 | INFO     | napari_assistant._gui._category_widget:call_op:185 - detect_label_edges (pyclesperanto_prototype)(..., )
# 2026-05-22 16:45:06.542 | INFO     | napari_assistant._gui._category_widget:call_op:185 - threshold_otsu (pyclesperanto_prototype)(..., )
# 2026-05-22 16:45:09.986 | INFO     | napari_assistant._gui._category_widget:call_op:185 - connected_components_labeling_box (pyclesperanto_prototype)(..., )
# 2026-05-22 16:45:37.853 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_labeling (pyclesperanto_prototype)(..., )
# 2026-05-22 16:45:50.360 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 2.0)
# 2026-05-22 16:45:59.539 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 3.0, 2.0)
# 2026-05-22 16:46:00.006 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 4.0, 2.0)
# 2026-05-22 16:46:01.061 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 5.0, 2.0)
# 2026-05-22 16:46:03.432 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 5.0, 3.0)
# 2026-05-22 16:46:05.505 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 5.0, 4.0)
# 2026-05-22 16:46:06.742 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 5.0, 5.0)
# 2026-05-22 16:46:07.882 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 5.0, 6.0)
# 2026-05-22 16:46:08.720 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 5.0, 7.0)
# 2026-05-22 16:46:14.990 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 4.0, 7.0)
# 2026-05-22 16:46:16.030 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 3.0, 7.0)
# 2026-05-22 16:46:21.489 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 3.0, 6.0)
# 2026-05-22 16:46:22.240 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 3.0, 5.0)
# 2026-05-22 16:46:23.051 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 3.0, 4.0)
# 2026-05-22 16:46:25.259 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 3.0, 3.0)
# 2026-05-22 16:46:27.221 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 3.0)
# 2026-05-22 16:46:30.323 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 3.0, 3.0)
# 2026-05-22 16:46:31.180 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 4.0, 3.0)
# 2026-05-22 16:47:06.237 | INFO     | napari_assistant._gui._category_widget:call_op:185 - binary_edge_detection (pyclesperanto_prototype)(..., )
# 2026-05-22 16:47:30.996 | INFO     | napari_assistant._gui._category_widget:call_op:185 - smooth_labels (pyclesperanto_prototype)(..., 2.0)
# 2026-05-22 16:48:26.925 | INFO     | napari_assistant._gui._category_widget:call_op:185 - maximum_of_distal_neighbors_map (pyclesperanto_prototype)(..., 1.0, 100.0)
# 2026-05-22 16:49:04.564 | INFO     | napari_assistant._gui._category_widget:call_op:185 - mode_of_touching_neighbors_map (pyclesperanto_prototype)(..., 1.0, False)
# 2026-05-22 16:49:14.318 | INFO     | napari_assistant._gui._category_widget:call_op:185 - mode_of_touching_neighbors_map (pyclesperanto_prototype)(..., 1.0, False)
# 2026-05-22 16:49:41.018 | INFO     | napari_assistant._gui._category_widget:call_op:185 - average_distance_to_n_nearest_other_labels_map (pyclesperanto_prototype)(..., 0.0)

# %% [markdown]
# # 3. Processing
# still quick and dirty (need to decide how to normalize stuff)

# %% [markdown]
# # 3.1 process cilia

# %% [markdown]
# we can train a classifier for the cilia as well as it is a bit more robust

# %%
from apoc import ObjectSegmenter

def cilia_process_3d_ml(volume,classifier_path="c:/Users/qfavey/Documents/Code-Thomas-Test/LimonCELLo/Segmenters/cilia-segmenter.cl",min_size=20):
    segmenter = ObjectSegmenter(opencl_filename=classifier_path)
    result = segmenter.predict(image=volume)
    filtered_result = cle.exclude_small_labels(cle.push(result), maximum_size=min_size)
    return filtered_result

# %%
cilia_labels = cilia_process_3d_ml(a[0,0])

# %%
viewer.add_labels(cilia_labels, name=f"cilia_labels_ml", blending="additive" )
# Out:
# <Labels layer 'cilia_labels_ml' at 0x201770666b0>

# %% [markdown]
# # 3.2 Process Nuclei
# The challenge here is that some of the nuclei come out but do not correspond to any neurites (difference in staining efficacy I guess) we want to exclude them from the analysis so that they do not get assigned any cilia. Quick and dirty way again voronoi otsu

# %%
def nuclei_process_3d(
    volume,
    tophat_radius=(2.0, 2.0, 2.0),
    dilation_radius=(2.0, 2.0, 2.0),
    min_size=50,
    spot_sigma = 5, 
    outline_sigma = 1
):
    """
    3D cilia segmentation pipeline on GPU.

    Parameters
    ----------
    volume : np.ndarray
        3D array (Z, Y, X)
    tophat_radius : tuple
        (rx, ry, rz) for 3D top-hat sphere
    dilation_radius : tuple
        (rx, ry, rz) for 3D label dilation
    min_size : int
        Minimum voxel size to keep objects
    spot_sigma: int
        How close detected cells can be
    outline_sigma: int
        How precise the segmented objects are outlined

    Returns
    -------
    result : np.ndarray
        3D labeled volume
    """

    # Push to GPU
    volume_gpu = cle.push(volume)

    # 3D top-hat (sphere)
    th_gpu = cle.top_hat_sphere(
        volume_gpu,
        radius_x=tophat_radius[2],
        radius_y=tophat_radius[2],
        radius_z=tophat_radius[2],
    )

    # 3D Otsu threshold
    labels_gpu = cle.voronoi_otsu_labeling(th_gpu,spot_sigma=spot_sigma, outline_sigma=outline_sigma)

    # Pull back to CPU
    result = cle.pull(labels_gpu)

    return result

# %% [markdown]
# run this:

# %%
nuclei_spot_sigma = 15
tophat_radius = 12
nuclei_labels_otsu = nuclei_process_3d(a[0,3],tophat_radius=(tophat_radius,tophat_radius,tophat_radius),spot_sigma=nuclei_spot_sigma,outline_sigma=3)
viewer.add_labels(nuclei_labels_otsu, name=f"nuclei_labels_otsu spot_sigma={nuclei_spot_sigma}", blending="additive", scale=scale, units='um' )
# Out:
# <Labels layer 'nuclei_labels_otsu spot_sigma=15' at 0x201770f8970>

# %% [markdown]
# We want to get the distance transform of the nuclei channel. Every voxel contains the distance to the nearest nucleus

# %%
distance_map = distance_transform_edt(~(nuclei_labels_otsu>0),sampling=meta['voxel_size'])

# %% [markdown]
# # 3.3 Process neurites
# The idea is to binarize with otsu or ML, use the binary mask to filter out the nuclei that are not in contact. Convert the skeleton to graph, get graph statistics (such as scholl analysis), assign cilia to closest branches and get statistics on the type of the assigned branches, also get closest nuclei to cilia. Hard to tell which cell they belong to in this picture. Additionally, semi automated soma labelling could help with this. And we would not need the dapi signal

# %%
import pyclesperanto_prototype as cle
import numpy as np
from skimage.filters import meijering
from skimage.morphology import skeletonize

def neurites_process_gpu(
    neurites,
    nuclei_labels,
    min_size=50,
    spot_sigma=10,
    outline_sigma=1,
    meijering_sigmas=(1, 2, 3),  # <-- NEW
):

    # ---- Push to GPU ----
    neurites_gpu = cle.push(neurites)
    nuclei_gpu = cle.push(nuclei_labels)

    # ---- Pull to CPU for Meijering ----
    neurites_cpu = cle.pull(neurites_gpu)

    # ---- Meijering tubular enhancement ----
    enhanced_cpu = meijering(
        neurites_cpu,
        sigmas=meijering_sigmas,
        black_ridges=False  # neurites = bright
    )

    # ---- Back to GPU ----
    enhanced_gpu = cle.push(enhanced_cpu.astype(np.float32))

    # ---- Segmentation (Voronoi Otsu on enhanced image) ----
    neurites_label = cle.exclude_small_labels(
        cle.voronoi_otsu_labeling(
            enhanced_gpu,
            spot_sigma=spot_sigma,
            outline_sigma=outline_sigma
        ),
        maximum_size=min_size
    )

    # ---- Skeletonize (CPU fallback) ----
    binary = cle.pull(neurites_label) > 0
    skeleton = skeletonize(binary)

    return skeleton, neurites_label

# %%
from skimage.filters import meijering

plt.imshow(meijering(a[0,1][10],sigmas = (1,2,5),black_ridges=False))

# %%
def basal_bodies_process_gpu(basal_bodies,spot_sigma=2,outline_sigma=2, gaussian_blur_kernel= [1.0,1.0,0.0]):

    basal_bodies_gpu = cle.push(basal_bodies)
    # gaussian blur

    image1_gbp = cle.gaussian_blur(basal_bodies_gpu, None, gaussian_blur_kernel[0], gaussian_blur_kernel[1], gaussian_blur_kernel[2])

    # voronoi otsu labeling

    image2_volp = cle.voronoi_otsu_labeling(image1_gbp, None,spot_sigma, outline_sigma)
    return image2_volp

# %%
bb_labels = basal_bodies_process_gpu(a[0,2])
viewer.add_labels(bb_labels,name=f'neurites label spot_sigma={2}', scale=scale, units='um')
# Out:
# <Labels layer 'neurites label spot_sigma=2' at 0x220ac5c77f0>
# 2026-03-25 12:01:14.402 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 2.0)
# 2026-03-25 12:02:04.835 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 1.0, 1.0, 0.0)
# 2026-03-25 12:02:15.065 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 1.0, 1.0, 0.0)
# 2026-03-25 12:02:38.263 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 2.0, 1.0, 0.0)
# 2026-03-25 12:02:40.367 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 2.0, 2.0, 0.0)
# 2026-03-25 12:02:41.914 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 2.0, 1.0, 0.0)
# 2026-03-25 12:02:42.542 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 1.0, 1.0, 0.0)
# 2026-03-25 12:03:10.753 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 1.0, 1.0, 1.0)
# 2026-03-25 12:03:12.706 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 1.0, 1.0, 0.0)
# 2026-03-25 12:03:20.554 | INFO     | napari_assistant._gui._category_widget:call_op:185 - bottom_hat_box (pyclesperanto_prototype)(..., 10.0, 10.0, 0.0)
# 2026-03-25 12:03:34.158 | INFO     | napari_assistant._gui._category_widget:call_op:185 - bottom_hat_box (pyclesperanto_prototype)(..., 10.0, 10.0, 0.0)
# 2026-03-25 12:03:38.905 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 10.0, 10.0, 0.0)
# 2026-03-25 12:04:19.703 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 1.0, 10.0, 0.0)
# 2026-03-25 12:04:21.453 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 1.0, 1.0, 0.0)
# 2026-03-25 12:04:24.878 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 1.0, 1.0, 1.0)
# 2026-03-25 12:04:30.047 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 2.0, 1.0, 1.0)
# 2026-03-25 12:04:30.390 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 20.0, 1.0, 1.0)
# 2026-03-25 12:04:32.771 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 20.0, 2.0, 1.0)
# 2026-03-25 12:04:33.186 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 20.0, 20.0, 1.0)
# 2026-03-25 12:04:35.885 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 20.0, 20.0, 2.0)
# 2026-03-25 12:04:36.254 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 20.0, 20.0, 20.0)
# 2026-03-25 12:04:44.268 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 0.0, 20.0, 20.0)
# 2026-03-25 12:04:44.650 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 10.0, 20.0, 20.0)
# 2026-03-25 12:04:46.910 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 10.0, 0.0, 20.0)
# 2026-03-25 12:04:47.285 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 10.0, 10.0, 20.0)
# 2026-03-25 12:04:49.566 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 10.0, 10.0, 0.0)
# 2026-03-25 12:04:49.926 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 10.0, 10.0, 10.0)
# 2026-03-25 12:04:53.240 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 5.0, 10.0, 10.0)
# 2026-03-25 12:04:53.598 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 50.0, 10.0, 10.0)
# 2026-03-25 12:04:55.509 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 50.0, 5.0, 10.0)
# 2026-03-25 12:04:55.913 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 50.0, 50.0, 10.0)
# 2026-03-25 12:04:58.277 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 50.0, 50.0, 5.0)
# 2026-03-25 12:04:58.712 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 50.0, 50.0, 50.0)
# 2026-03-25 12:05:10.994 | INFO     | napari_assistant._gui._category_widget:call_op:185 - absolute (pyclesperanto_prototype)(..., )
# 2026-03-25 12:05:29.909 | INFO     | napari_assistant._gui._category_widget:call_op:185 - large_hessian_eigenvalue (pyclesperanto_prototype)(..., )
# 2026-03-25 12:05:32.915 | INFO     | napari_assistant._gui._category_widget:call_op:185 - laplace_box (pyclesperanto_prototype)(..., )
# 2026-03-25 12:05:38.022 | INFO     | napari_assistant._gui._category_widget:call_op:185 - log (pyclesperanto_prototype)(..., )
# 2026-03-25 12:05:43.269 | INFO     | napari_assistant._gui._category_widget:call_op:185 - sobel (pyclesperanto_prototype)(..., )
# 2026-03-25 12:06:17.173 | INFO     | napari_assistant._gui._category_widget:call_op:185 - opening_box (pyclesperanto_prototype)(..., 1.0, 1.0, 0.0)
# 2026-03-25 12:06:20.348 | INFO     | napari_assistant._gui._category_widget:call_op:185 - opening_box (pyclesperanto_prototype)(..., 10.0, 1.0, 0.0)
# 2026-03-25 12:06:23.403 | INFO     | napari_assistant._gui._category_widget:call_op:185 - opening_box (pyclesperanto_prototype)(..., 10.0, 10.0, 0.0)
# 2026-03-25 12:06:26.943 | INFO     | napari_assistant._gui._category_widget:call_op:185 - opening_box (pyclesperanto_prototype)(..., 10.0, 10.0, 1.0)
# 2026-03-25 12:06:27.207 | INFO     | napari_assistant._gui._category_widget:call_op:185 - opening_box (pyclesperanto_prototype)(..., 10.0, 10.0, 10.0)
# 2026-03-25 12:06:38.746 | INFO     | napari_assistant._gui._category_widget:call_op:185 - variance_box (pyclesperanto_prototype)(..., 10.0, 10.0, 10.0)
# 2026-03-25 12:07:05.397 | INFO     | napari_assistant._gui._category_widget:call_op:185 - connected_components_labeling_box (pyclesperanto_prototype)(..., )
# 2026-03-25 12:07:17.429 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 2.0)
# 2026-03-25 12:07:20.974 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 1.0, 2.0)
# 2026-03-25 12:07:21.496 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 10.0, 2.0)
# 2026-03-25 12:07:27.305 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 2.0)
# 2026-03-25 12:07:27.874 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 20.0, 2.0)
# 2026-03-25 12:07:37.319 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 20.0, 2.0)
# 2026-03-25 12:07:41.757 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 20.0, 2.0)
# 2026-03-25 12:07:56.613 | INFO     | napari_assistant._gui._category_widget:call_op:185 - absolute (pyclesperanto_prototype)(..., )
# 2026-03-25 12:08:11.060 | INFO     | napari_assistant._gui._category_widget:call_op:185 - sobel (pyclesperanto_prototype)(..., )
# 2026-03-25 12:08:17.946 | INFO     | napari_assistant._gui._category_widget:call_op:185 - connected_components_labeling_box (pyclesperanto_prototype)(..., )
# 2026-03-25 12:08:28.243 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 2.0)
# 2026-03-25 12:08:33.643 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 2.0)
# 2026-03-25 12:08:40.383 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 1.0, 2.0)
# 2026-03-25 12:08:40.933 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 10.0, 2.0)
# 2026-03-25 12:08:56.545 | INFO     | napari_assistant._gui._category_widget:call_op:185 - eroded_otsu_labeling (pyclesperanto_prototype)(..., 10.0, 2.0)
# 2026-03-25 12:09:09.893 | INFO     | napari_assistant._gui._category_widget:call_op:185 - eroded_otsu_labeling (pyclesperanto_prototype)(..., 1.0, 2.0)
# 2026-03-25 12:09:14.581 | INFO     | napari_assistant._gui._category_widget:call_op:185 - eroded_otsu_labeling (pyclesperanto_prototype)(..., 0.0, 2.0)
# 2026-03-25 12:09:18.175 | INFO     | napari_assistant._gui._category_widget:call_op:185 - eroded_otsu_labeling (pyclesperanto_prototype)(..., 5.0, 2.0)
# 2026-03-25 12:09:27.818 | INFO     | napari_assistant._gui._category_widget:call_op:185 - connected_components_labeling_diamond (pyclesperanto_prototype)(..., )
# 2026-03-25 12:09:45.337 | INFO     | napari_assistant._gui._category_widget:call_op:185 - detect_label_edges (pyclesperanto_prototype)(..., )
# 2026-03-25 12:09:53.496 | INFO     | napari_assistant._gui._category_widget:call_op:185 - detect_label_edges (pyclesperanto_prototype)(..., )
# 2026-03-25 12:10:04.826 | INFO     | napari_assistant._gui._category_widget:call_op:185 - greater_or_equal_constant (pyclesperanto_prototype)(..., 1.0)
# 2026-03-25 12:10:08.317 | INFO     | napari_assistant._gui._category_widget:call_op:185 - threshold_otsu (pyclesperanto_prototype)(..., )
# 2026-03-25 12:10:26.067 | INFO     | napari_assistant._gui._category_widget:call_op:185 - connected_components_labeling_box (pyclesperanto_prototype)(..., )
# 2026-03-25 12:10:39.306 | INFO     | napari_assistant._gui._category_widget:call_op:185 - connected_components_labeling_box (pyclesperanto_prototype)(..., )
# 2026-03-25 12:10:57.377 | INFO     | napari_assistant._gui._category_widget:call_op:185 - connected_components_labeling_box (pyclesperanto_prototype)(..., )
# 2026-03-25 12:11:10.596 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 2.0)
# 2026-03-25 12:11:17.139 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 1.0)
# 2026-03-25 12:11:24.775 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 2.0)
# 2026-03-25 12:11:38.638 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 1.0, 1.0, 0.0)
# 2026-03-25 12:11:45.154 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 1.0, 1.0, 0.0)
# 2026-03-25 12:11:50.479 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 10.0, 1.0, 0.0)
# 2026-03-25 12:11:52.110 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 10.0, 10.0, 0.0)
# 2026-03-25 12:11:54.610 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 10.0, 10.0, 10.0)
# 2026-03-25 12:12:10.878 | INFO     | napari_assistant._gui._category_widget:call_op:185 - bottom_hat_box (pyclesperanto_prototype)(..., 10.0, 10.0, 0.0)
# 2026-03-25 12:12:16.717 | INFO     | napari_assistant._gui._category_widget:call_op:185 - bottom_hat_box (pyclesperanto_prototype)(..., 10.0, 10.0, 0.0)
# 2026-03-25 12:12:22.495 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 10.0, 10.0, 0.0)
# 2026-03-25 12:12:28.565 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 1.0, 10.0, 0.0)
# 2026-03-25 12:12:28.821 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 0.0, 10.0, 0.0)
# 2026-03-25 12:12:30.013 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 5.0, 10.0, 0.0)
# 2026-03-25 12:12:33.474 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 5.0, 1.0, 0.0)
# 2026-03-25 12:12:33.725 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 5.0, 0.0, 0.0)
# 2026-03-25 12:12:33.978 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 5.0, 5.0, 0.0)
# 2026-03-25 12:12:37.607 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 5.0, 5.0, 5.0)
# 2026-03-25 12:13:48.760 | INFO     | napari_assistant._gui._category_widget:call_op:185 - connected_components_labeling_diamond (pyclesperanto_prototype)(..., )
# 2026-03-25 12:13:57.891 | INFO     | napari_assistant._gui._category_widget:call_op:185 - threshold_otsu (pyclesperanto_prototype)(..., )
# 2026-03-25 12:13:59.125 | INFO     | napari_assistant._gui._category_widget:call_op:185 - connected_components_labeling_box (pyclesperanto_prototype)(..., )
# 2026-03-25 12:14:05.833 | INFO     | napari_assistant._gui._category_widget:call_op:185 - voronoi_otsu_labeling (pyclesperanto_prototype)(..., 2.0, 2.0)
# 2026-03-25 12:14:07.568 | INFO     | napari_assistant._gui._category_widget:call_op:185 - gaussian_blur (pyclesperanto_prototype)(..., 10.0, 10.0, 10.0)
# 2026-03-25 12:14:09.233 | INFO     | napari_assistant._gui._category_widget:call_op:185 - subtract_gaussian_background (pyclesperanto_prototype)(..., 5.0, 5.0, 5.0)
# adding: gaussian_blur=10
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10
# adding: difference_of_gaussian=10
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10
# adding: laplace_box_of_gaussian_blur=10
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10
# adding: sobel_of_gaussian_blur=10
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10  sobel_of_gaussian_blur=10
# adding: difference_of_gaussian=2
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10  sobel_of_gaussian_blur=10  difference_of_gaussian=2
# adding: gaussian_blur=2
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10  sobel_of_gaussian_blur=10  difference_of_gaussian=2  gaussian_blur=2
# adding: laplace_box_of_gaussian_blur=2
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10  sobel_of_gaussian_blur=10  difference_of_gaussian=2  gaussian_blur=2  laplace_box_of_gaussian_blur=2
# adding: sobel_of_gaussian_blur=2
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10  sobel_of_gaussian_blur=10  difference_of_gaussian=2  gaussian_blur=2  laplace_box_of_gaussian_blur=2  sobel_of_gaussian_blur=2
# adding: gaussian_blur=3
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10  sobel_of_gaussian_blur=10  difference_of_gaussian=2  gaussian_blur=2  laplace_box_of_gaussian_blur=2  sobel_of_gaussian_blur=2  gaussian_blur=3
# adding: difference_of_gaussian=3
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10  sobel_of_gaussian_blur=10  difference_of_gaussian=2  gaussian_blur=2  laplace_box_of_gaussian_blur=2  sobel_of_gaussian_blur=2  gaussian_blur=3  difference_of_gaussian=3
# adding: laplace_box_of_gaussian_blur=3
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10  sobel_of_gaussian_blur=10  difference_of_gaussian=2  gaussian_blur=2  laplace_box_of_gaussian_blur=2  sobel_of_gaussian_blur=2  gaussian_blur=3  difference_of_gaussian=3  laplace_box_of_gaussian_blur=3
# adding: sobel_of_gaussian_blur=3
#  gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1  gaussian_blur=10  difference_of_gaussian=10  laplace_box_of_gaussian_blur=10  sobel_of_gaussian_blur=10  difference_of_gaussian=2  gaussian_blur=2  laplace_box_of_gaussian_blur=2  sobel_of_gaussian_blur=2  gaussian_blur=3  difference_of_gaussian=3  laplace_box_of_gaussian_blur=3  sobel_of_gaussian_blur=3
# train ObjectSegmenter
# num images 1
# object annotation value 2
# features gaussian_blur=1 difference_of_gaussian=1 laplace_box_of_gaussian_blur=1 sobel_of_gaussian_blur=1 gaussian_blur=10 difference_of_gaussian=10 laplace_box_of_gaussian_blur=10 sobel_of_gaussian_blur=10 difference_of_gaussian=2 gaussian_blur=2 laplace_box_of_gaussian_blur=2 sobel_of_gaussian_blur=2 gaussian_blur=3 difference_of_gaussian=3 laplace_box_of_gaussian_blur=3 sobel_of_gaussian_blur=3
# depth 3
# num trees 100
# file c:/Users/qfavey/Documents/Code-Thomas-Test/LimonCELLo/NeuriteSegmenter3.cl
# annotation shape (23, 2040, 2040)
# Training done. Applying model...
# Applying / prediction done.

# %%
spot_sigma = 5
binary_skeleton, neurites_label = neurites_process_gpu(a[0,1],nuclei_labels_otsu,spot_sigma=spot_sigma)
viewer.add_labels(neurites_label,name=f'neurites label spot_sigma={spot_sigma}', scale=scale, units='um')
viewer.add_image(binary_skeleton,name=f"skeleton spot_sigma={spot_sigma}",colormap="inferno", scale=scale, units='um')
# Out:
# <Image layer 'skeleton spot_sigma=5' at 0x2017aef2560>

# %% [markdown]
# Merge nuclei and neurites to one label for further classification into soma and dentrites/axon types

# %%
def merge_nuclei_neurites(labels_nuclei,labels_neurites,spot_sigma=10,outline_sigma=1):
    # binary or
    image2_bup = cle.binary_or(labels_nuclei, labels_neurites)
    image3_volp = cle.voronoi_otsu_labeling(image2_bup, None, spot_sigma, outline_sigma)
    return image3_volp

# %%
nuclei_neurites_merge = merge_nuclei_neurites(nuclei_labels_otsu,neurites_label)
viewer.add_labels(nuclei_neurites_merge, name=f'nuclei merged with neurites')
# Out:
# <Labels layer 'nuclei merged with neurites' at 0x201597e9450>

# %% [markdown]
# ## Distance transform shite

# %%
#dt_neurites = distance_map * np.array(neurites_label)
distance_map_neurites = distance_transform_edt(np.array(neurites_label)>0,sampling=meta['voxel_size']) # how thick are the neurites
viewer.add_image(distance_map_neurites,name="dt_neurites", colormap='viridis',)
# Out:
# C:\Users\qfavey\AppData\Local\Temp\ipykernel_91712\2020623555.py:2: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   distance_map_neurites = distance_transform_edt(np.array(neurites_label)>0,sampling=meta['voxel_size']) # how thick are the neurites
# <Image layer 'dt_neurites' at 0x201776b1d20>

# %%
# Compute raw ratio
map_ratio = distance_map_neurites / distance_map

# Replace infinities (div by zero) with NaN
map_ratio[np.isinf(map_ratio)] = np.nan

# Log ratio, safely ignoring non-positive values
log_map_ratio = np.full_like(map_ratio, np.nan, dtype=np.float64)
positive_mask = map_ratio > 0
log_map_ratio[positive_mask] = np.log(map_ratio[positive_mask])

# Normalize (z-score)
norm_map_ratio = (map_ratio - np.mean(map_ratio)) / np.std(map_ratio)
norm_log_map_ratio = (log_map_ratio - np.mean(log_map_ratio)) / np.std(log_map_ratio)

viewer.add_image(log_map_ratio,name="thickness/nuclei_dist ratio", colormap='viridis',)
# Out:
# C:\Users\qfavey\AppData\Local\Temp\ipykernel_91712\3639701481.py:2: RuntimeWarning: divide by zero encountered in divide
#   map_ratio = distance_map_neurites / distance_map
# C:\Users\qfavey\AppData\Local\Temp\ipykernel_91712\3639701481.py:2: RuntimeWarning: invalid value encountered in divide
#   map_ratio = distance_map_neurites / distance_map
# <Image layer 'thickness/nuclei_dist ratio' at 0x201636f4a90>

# %%
import numpy as np
import matplotlib.pyplot as plt

# --- Compute raw ratio safely ---
map_ratio = distance_map / distance_map_neurites

# Mask invalid values
map_ratio_clean = map_ratio.copy()
map_ratio_clean[~np.isfinite(map_ratio_clean)] = np.nan  # NaN for inf or -inf

# --- Log ratio safely ---
log_map_ratio = np.full_like(map_ratio_clean, np.nan)
positive_mask = map_ratio_clean > 0
log_map_ratio[positive_mask] = np.log(map_ratio_clean[positive_mask])

# --- Normalizations (robust to NaNs) ---
# Min-max
map_ratio_minmax = (map_ratio_clean - np.nanmin(map_ratio_clean)) / (np.nanmax(map_ratio_clean) - np.nanmin(map_ratio_clean))
log_map_ratio_minmax = (log_map_ratio - np.nanmin(log_map_ratio)) / (np.nanmax(log_map_ratio) - np.nanmin(log_map_ratio))

# Z-score
map_ratio_z = (map_ratio_clean - np.nanmean(map_ratio_clean)) / np.nanstd(map_ratio_clean)
log_map_ratio_z = (log_map_ratio - np.nanmean(log_map_ratio)) / np.nanstd(log_map_ratio)

# Logistic probability from log ratio
prob_neurite = np.full_like(map_ratio, np.nan)
prob_mask = np.isfinite(map_ratio)
prob_neurite[prob_mask] = 1 / (1 + np.exp(-log_map_ratio[prob_mask]))

# --- Choose middle slice for visualization ---
slice_idx = map_ratio.shape[0] // 2

# --- Prepare figure ---
fig, axes = plt.subplots(3, 3, figsize=(24, 15))
axes = axes.ravel()

# Original maps
im0 = axes[0].imshow(distance_map_neurites[slice_idx], cmap='turbo')
axes[0].set_title('Neurites distance map')
plt.colorbar(im0, ax=axes[0], fraction=0.046, pad=0.04)

im1 = axes[1].imshow(distance_map[slice_idx], cmap='turbo')
axes[1].set_title('Nuclei distance map')
plt.colorbar(im1, ax=axes[1], fraction=0.046, pad=0.04)

im2 = axes[2].imshow(map_ratio_clean[slice_idx], cmap='turbo')
axes[2].set_title('Neurites/Nuclei ratio')
plt.colorbar(im2, ax=axes[2], fraction=0.046, pad=0.04)

im3 = axes[3].imshow(log_map_ratio[slice_idx], cmap='turbo')
axes[3].set_title('Log ratio')
plt.colorbar(im3, ax=axes[3], fraction=0.046, pad=0.04)

# Normalized maps
im4 = axes[4].imshow(map_ratio_minmax[slice_idx], cmap='turbo', vmin=0, vmax=1)
axes[4].set_title('Ratio (min-max)')
plt.colorbar(im4, ax=axes[4], fraction=0.046, pad=0.04)

im5 = axes[5].imshow(log_map_ratio_minmax[slice_idx], cmap='turbo', vmin=0, vmax=1)
axes[5].set_title('Log ratio (min-max)')
plt.colorbar(im5, ax=axes[5], fraction=0.046, pad=0.04)

im6 = axes[6].imshow(map_ratio_z[slice_idx], cmap='turbo')
axes[6].set_title('Ratio (z-score)')
plt.colorbar(im6, ax=axes[6], fraction=0.046, pad=0.04)

im7 = axes[7].imshow(log_map_ratio_z[slice_idx], cmap='turbo')
axes[7].set_title('Log ratio (z-score)')
plt.colorbar(im7, ax=axes[7], fraction=0.046, pad=0.04)

# Logistic probability map
im8 = axes[8].imshow(prob_neurite[slice_idx], cmap='turbo', vmin=0, vmax=1)
axes[8].set_title('Logistic probability (axon likelihood) of ratio')
plt.colorbar(im8, ax=axes[8], fraction=0.046, pad=0.04)

# Remove axes ticks
for ax in axes:
    ax.axis('off')

plt.tight_layout()
plt.show()
# Out:
# C:\Users\qfavey\AppData\Local\Temp\ipykernel_29152\2027306674.py:5: RuntimeWarning: divide by zero encountered in divide
#   map_ratio = distance_map / distance_map_neurites
# C:\Users\qfavey\AppData\Local\Temp\ipykernel_29152\2027306674.py:5: RuntimeWarning: invalid value encountered in divide
#   map_ratio = distance_map / distance_map_neurites

# %%
viewer.add_image(log_map_ratio_z,name="thickness/nuclei_dist ratio", colormap='turbo',)
# Out:
# <Image layer 'thickness/nuclei_dist ratio [1]' at 0x1fd1480a7a0>

# %%
plt.hist(log_map_ratio_minmax.ravel(), bins=100)
plt.xlabel("map_ratio")
plt.ylabel("Count")
plt.title(f"Histogram of log map z-score")
plt.show()

# %% [markdown]
# # 4. Analysis

# %%
print(np.max(neurites_label))
# Out:
# 1364.0

# %%
import numpy as np
from scipy.ndimage import distance_transform_edt, center_of_mass



# Distance transform: distance from each voxel to nearest neurite voxel

# %%
import numpy as np
from scipy.ndimage import distance_transform_edt, center_of_mass
import matplotlib.pyplot as plt

# -------------------------
# INPUTS
# -------------------------
# cilia_labels : 3D label image (0 background, >0 individual cilia)
# neurite_mask : 3D binary neurite segmentation
# map_probability : 3D map giving probability voxel belongs to axon

# -------------------------
# 1. Compute nearest neurite for every voxel
# -------------------------

dist_to_neurite, nearest_idx= distance_transform_edt(~(np.array(neurites_label)>0), return_indices=True,sampling=meta['voxel_size'])


# -------------------------
# 2. Get cilia centroids
# -------------------------
cilia_ids = np.unique(cilia_labels)
cilia_ids = cilia_ids[cilia_ids != 0]

centroids = center_of_mass(cilia_labels > 0, labels=cilia_labels, index=cilia_ids)

# -------------------------
# 3. Map each centroid to nearest neurite voxel
# -------------------------
cilia_scores = {}
neurite_thickness = {}
# Out:
# C:\Users\qfavey\AppData\Local\Temp\ipykernel_29152\83763779.py:16: DeprecationWarning: __array__ implementation doesn't accept a copy keyword, so passing copy=False failed. __array__ must implement 'dtype' and 'copy' keyword arguments. To learn more, see the migration guide https://numpy.org/devdocs/numpy_2_0_migration_guide.html#adapting-to-changes-in-the-copy-keyword
#   dist_to_neurite, nearest_idx= distance_transform_edt(~(np.array(neurites_label)>0), return_indices=True,sampling=meta['voxel_size'])

# %%
for cid, c in zip(cilia_ids, centroids):

    z, y, x = np.round(c).astype(int)

    z = np.clip(z, 0, cilia_labels.shape[0]-1)
    y = np.clip(y, 0, cilia_labels.shape[1]-1)
    x = np.clip(x, 0, cilia_labels.shape[2]-1)

    # nearest neurite voxel
    nz, ny, nx = nearest_idx[:, z, y, x]

    # probability at that neurite location
    p = map_ratio_z[nz, ny, nx]
    neur_thickness = distance_map_neurites[nz, ny, nx]

    cilia_scores[cid] = p
    neurite_thickness[cid] = neurite_thickness

   
print(cilia_scores)
# Out:
# {np.uint32(1): np.float64(-0.11390263311941698), np.uint32(2): np.float64(-0.28732727958959015), np.uint32(3): np.float64(-0.15728484738323814), np.uint32(4): np.float64(-0.5593449505134174), np.uint32(5): np.float64(-0.21135544064830933), np.uint32(6): np.float64(-0.44383240073110275), np.uint32(7): np.float64(-0.481297029392204), np.uint32(8): np.float64(4.285537560556663), np.uint32(9): np.float64(-0.488424706997878), np.uint32(10): np.float64(-0.12115022420151275), np.uint32(11): np.float64(-0.4066998397723595), np.uint32(12): np.float64(3.1713496909510392), np.uint32(13): np.float64(-0.18118553919227048), np.uint32(14): np.float64(-0.5518056619055793), np.uint32(15): np.float64(-0.22636330055345702), np.uint32(16): np.float64(-0.19534003611091622), np.uint32(17): np.float64(-0.15180198291746533), np.uint32(18): np.float64(-0.6185555885693844), np.uint32(19): np.float64(0.7548333156990601), np.uint32(20): np.float64(-0.6282296447642177), np.uint32(21): np.float64(-0.561879760736969), np.uint32(22): np.float64(-0.353701769196703), np.uint32(23): np.float64(-0.3515317670358165), np.uint32(24): np.float64(-0.38268444816919106), np.uint32(25): np.float64(-0.5531414366255515), np.uint32(26): np.float64(-0.6282296447642177), np.uint32(27): np.float64(0.21784301648138898), np.uint32(28): np.float64(-0.26967034788418387), np.uint32(29): np.float64(-0.5350137389172883), np.uint32(30): np.float64(-0.012672509336662403), np.uint32(31): np.float64(-0.4399050757961877), np.uint32(32): np.float64(-0.6165502507999294), np.uint32(33): np.float64(0.4318173333422517), np.uint32(34): np.float64(0.5338800798188594), np.uint32(35): np.float64(0.5389076262242657), np.uint32(36): np.float64(-0.45119184410787894), np.uint32(37): np.float64(-0.4399050757961877), np.uint32(38): np.float64(-0.6171415901963186), np.uint32(39): np.float64(0.02955979569475646), np.uint32(40): np.float64(-0.07567345786915225), np.uint32(41): np.float64(0.0888889489958501), np.uint32(42): np.float64(-0.47817060324505145), np.uint32(43): np.float64(-0.5486922876227284), np.uint32(44): np.float64(0.5520492984957849), np.uint32(45): np.float64(-0.5532001240046346), np.uint32(46): np.float64(-0.23612959877272632), np.uint32(47): np.float64(-0.3720805376753203), np.uint32(48): np.float64(0.5532711442085425), np.uint32(49): np.float64(0.4127392711075162), np.uint32(50): np.float64(0.5651233035584143), np.uint32(51): np.float64(-0.6096019892997014), np.uint32(52): np.float64(0.5651233035584143), np.uint32(53): np.float64(0.6354408427627594), np.uint32(54): np.float64(0.035162911817925926), np.uint32(55): np.float64(0.10014412568947466), np.uint32(56): np.float64(-0.5091227293025297), np.uint32(57): np.float64(-0.13713925157416443), np.uint32(58): np.float64(-0.4399050757961877), np.uint32(59): np.float64(-0.47639752322846923), np.uint32(60): np.float64(-0.6282296447642177), np.uint32(61): np.float64(2.356936996269134), np.uint32(62): np.float64(0.7193112769825422), np.uint32(63): np.float64(-0.6282296447642177), np.uint32(64): np.float64(-0.6282296447642177), np.uint32(65): np.float64(0.007173288239458052), np.uint32(66): np.float64(-0.3240562073735594), np.uint32(67): np.float64(0.05491696584461678), np.uint32(68): np.float64(2.718706469660234), np.uint32(69): np.float64(-0.09224852518662129), np.uint32(70): np.float64(0.13732768009939472), np.uint32(71): np.float64(-0.481297029392204), np.uint32(72): np.float64(-0.4471048741467793), np.uint32(73): np.float64(2.7597811686186446), np.uint32(74): np.float64(-0.16755653552741365), np.uint32(75): np.float64(3.572648328772302), np.uint32(76): np.float64(0.10720130710969059), np.uint32(77): np.float64(-0.4066998397723595), np.uint32(78): np.float64(0.31637768683461653), np.uint32(79): np.float64(-0.4066998397723595), np.uint32(80): np.float64(-0.05133745317580229), np.uint32(81): np.float64(0.7130459114603545), np.uint32(82): np.float64(2.3357142969646887), np.uint32(83): np.float64(0.2695276197397768)}

# %%
# -------------------------
# 4. Create cilia probability map
# -------------------------
cilia_prob_map = np.zeros_like(cilia_labels, dtype=float)

# Create lookup table
lut = np.zeros(int(cilia_labels.max() + 1))

for cid, p in cilia_scores.items():
    lut[cid] = p

# Map labels to probabilities in one pass
cilia_prob_map = lut[cilia_labels]

# %%
# -------------------------
# 5. Visualize
# -------------------------
slice_idx = cilia_labels.shape[0] // 2

fig, ax = plt.subplots(1,1, figsize=(6,6))

im = ax.imshow(cilia_prob_map[slice_idx], cmap="viridis", vmin=0, vmax=1)
ax.set_title("Cilia colored by axon probability")
ax.axis("off")

plt.colorbar(im, ax=ax)
plt.show()

# %%
distances = []

for centroid in centroids:

    z, y, x = np.round(centroid).astype(int)
    d = dist_to_neurite[z, y, x]
    distances.append(d)

plt.hist(distances, bins=50)
plt.xlabel("Distance to nearest neurite (um)")
plt.ylabel("Number of cilia")
plt.title("Cilia → neurite distance distribution")
plt.show()

# %%
max_distance_um = 2.0

filtered_cilia_ids = []
filtered_centroids = []

for cid, centroid in zip(cilia_ids, centroids):

    z, y, x = np.round(centroid).astype(int)

    z = np.clip(z, 0, dist_to_neurite.shape[0]-1)
    y = np.clip(y, 0, dist_to_neurite.shape[1]-1)
    x = np.clip(x, 0, dist_to_neurite.shape[2]-1)

    d = dist_to_neurite[z, y, x]

    if d <= max_distance_um:
        filtered_cilia_ids.append(cid)
        filtered_centroids.append(centroid)

# %%
distances = []

for centroid in filtered_centroids:

    z, y, x = np.round(centroid).astype(int)
    d = dist_to_neurite[z, y, x]
    distances.append(d)

plt.hist(distances, bins=50)
plt.xlabel("Distance to nearest neurite (um)")
plt.ylabel("Number of cilia")
plt.title("Cilia → neurite distance distribution")
plt.show()

# %%
viewer.add_image(cilia_prob_map)
# Out:
# <Image layer 'cilia_prob_map' at 0x1fc9e40e710>

# %%
import numpy as np
from scipy.ndimage import center_of_mass

vectors = []

for cid, centroid in zip(filtered_cilia_ids, filtered_centroids):

    z, y, x = np.round(centroid).astype(int)

    z = np.clip(z, 0, cilia_labels.shape[0]-1)
    y = np.clip(y, 0, cilia_labels.shape[1]-1)
    x = np.clip(x, 0, cilia_labels.shape[2]-1)

    # nearest neurite voxel
    nz, ny, nx = nearest_idx[:, z, y, x]

    start = np.array([z, y, x])
    end = np.array([nz, ny, nx])

    direction = end - start

    vectors.append([start, direction])

vectors = np.array(vectors)

# %%
viewer.add_vectors(
    vectors,
    name="cilia_to_neurite_vectors",
    edge_width=2,
    length=1,
)
# Out:
# <Vectors layer 'cilia_to_neurite_vectors' at 0x1fcb4ca2770>

# %%
import numpy as np

scores = np.array(list(cilia_scores.values()))
scores = scores[filtered_cilia_ids]
axon = np.sum(scores > 0.6)
soma = np.sum(scores < 0.2)
ambiguous = np.sum((scores >= 0.2) & (scores <= 0.6))

# %%
import matplotlib.pyplot as plt

labels = ["Soma", "Ambiguous", "Axon"]
counts = [soma, ambiguous, axon]

plt.figure(figsize=(6,5))
plt.bar(labels, counts)
plt.ylabel("Number of cilia")
plt.title("Cilia connection class distribution")
plt.show()

# %%
plt.figure(figsize=(6,5))

plt.hist(scores, bins=30)
plt.xlabel("Axon probability")
plt.ylabel("Number of cilia")
plt.title("Distribution of cilia connection probabilities")

plt.show()

# %%
plt.figure(figsize=(6,5))

plt.pie(
    counts,
    labels=labels,
    autopct="%1.1f%%"
)

plt.title("Fraction of cilia connected to soma vs axon")
plt.show()

# %%
filtered_points = np.array(filtered_centroids)

viewer.add_points(
    filtered_points,
    name="filtered_cilia",
    size=6,
    face_color="cyan",
    
)
# Out:
# <Points layer 'filtered_cilia' at 0x1fd0ba5dc90>

# %%
plt.plot(neurite_thickness)
# Out:
# (array([9., 8., 8., 8., 8., 9., 8., 8., 8., 9.]),
#  array([ 1. ,  9.2, 17.4, 25.6, 33.8, 42. , 50.2, 58.4, 66.6, 74.8, 83. ]),
#  <BarContainer object of 10 artists>)
